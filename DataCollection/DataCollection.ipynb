# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd

# %%
stats = pd.DataFrame()

# %%
for offset in range(0,32):
    # URL page we will scraping (see image above)
    url = "https://www.basketball-reference.com/play-index/psl_finder.cgi?request=1&match=single&type=per_game&per_minute_base=36&per_poss_base=100&lg_id=NBA&is_playoffs=N&year_min=1997&year_max=2020&franch_id=&season_start=1&season_end=2&age_min=0&age_max=99&shoot_hand=&height_min=0&height_max=99&birth_country_is=Y&birth_country=&birth_state=&college_id=&draft_year=&is_active=&debut_yr_nba_start=&debut_yr_nba_end=&is_hof=&is_as=&as_comp=gt&as_val=0&award=&pos_is_g=Y&pos_is_gf=Y&pos_is_f=Y&pos_is_fg=Y&pos_is_fc=Y&pos_is_c=Y&pos_is_cf=Y&qual=&c1stat=&c1comp=&c1val=&c2stat=&c2comp=&c2val=&c3stat=&c3comp=&c3val=&c4stat=&c4comp=&c4val=&c5stat=&c5comp=&c6mult=&c6stat=&order_by=player&order_by_asc=&offset={}".format(str(offset*100))
    
    # this is the HTML from the given URL
    html = urlopen(url)
    soup = BeautifulSoup(html)
    # use findALL() to get the column headers
    soup.findAll('tr', limit=2)
    # use getText()to extract the text we need into a list
    headers = [th.getText() for th in soup.findAll('tr', limit=2)[1].findAll('th')]
    # exclude the first column as we will not need the ranking order from Basketball Reference for the analysis
    headers = headers[1:]
    # avoid the first header row
    rows = soup.findAll('tr')[1:]
    
    
    player_stats = [[td.getText() for td in rows[i].findAll('td')]
                for i in range(len(rows))]
    
    stats = pd.concat([stats, pd.DataFrame(player_stats, columns = headers)]).reset_index(drop=True)

# %%
stats = stats[1:]

# %%
stats.head(10)
# Out:
#      Season Age   Tm   Lg               Player   G  GS    MP   FG  FGA  ...  \
# 1   1996-97  29  POR  NBA  Aleksandar Đorđević   8   0   7.6  1.0  2.0  ...
# 2   2017-18  20  LAL  NBA          Ivica Zubac  43   0   9.5  1.4  2.8  ...
# 3   2016-17  19  LAL  NBA          Ivica Zubac  38  11  16.0  3.3  6.3  ...
# 4   2018-19  22  CLE  NBA           Ante Žižić  59  25  18.3  3.1  5.6  ...
# 5   2017-18  21  CLE  NBA           Ante Žižić  32   2   6.7  1.5  2.1  ...
# 6   2016-17  22  CHI  NBA          Paul Zipser  44  18  19.2  2.0  5.0  ...
# 7   2017-18  23  CHI  NBA          Paul Zipser  54  12  15.3  1.5  4.3  ...
# 8   2016-17  20  ORL  NBA    Stephen Zimmerman  19   0   5.7  0.5  1.6  ...
# 9   2005-06  24  NJN  NBA    Derrick Zimmerman   2   0  16.0  1.0  1.5  ...
# 10  1996-97  23  TOT  NBA         George Zídek  52   2   7.2  0.9  2.3  ...
#
#     BLK  TOV   PF  PTS   FG%   2P%   3P%  eFG%   FT%   TS%
# 1   0.0  0.6  0.4  3.1  .500  .333  .714  .656  .800  .687
# 2   0.3  0.6  1.1  3.7  .500  .504  .000  .500  .765  .557
# 3   0.9  0.8  1.7  7.5  .529  .536  .000  .529  .653  .547
# 4   0.4  1.0  1.9  7.8  .553  .553        .553  .705  .590
# 5   0.4  0.3  0.9  3.7  .731  .731        .731  .724  .746
# 6   0.4  0.9  1.8  5.5  .398  .451  .333  .473  .775  .503
# 7   0.3  0.8  1.6  4.0  .346  .355  .336  .425  .760  .445
# 8   0.3  0.2  0.9  1.2  .323  .323        .323  .600  .346
# 9   0.0  2.0  2.0  2.0  .667  .667        .667        .667
# 10  0.1  0.5  1.2  2.8  .415  .422  .000  .415  .789  .500
#
# [10 rows x 31 columns]

# %%
stats.shape
# Out:
# (3359, 31)

# %%
stats_adv = pd.DataFrame()

# %%
for offset in range(0,32):
    # URL page we will scraping
    url = "https://www.basketball-reference.com/play-index/psl_finder.cgi?request=1&match=single&type=advanced&per_minute_base=36&per_poss_base=100&lg_id=NBA&is_playoffs=N&year_min=1997&year_max=2020&franch_id=&season_start=1&season_end=2&age_min=0&age_max=99&shoot_hand=&height_min=0&height_max=99&birth_country_is=Y&birth_country=&birth_state=&college_id=&draft_year=&is_active=&debut_yr_nba_start=&debut_yr_nba_end=&is_hof=&is_as=&as_comp=gt&as_val=0&award=&pos_is_g=Y&pos_is_gf=Y&pos_is_f=Y&pos_is_fg=Y&pos_is_fc=Y&pos_is_c=Y&pos_is_cf=Y&qual=&c1stat=&c1comp=&c1val=&c2stat=&c2comp=&c2val=&c3stat=&c3comp=&c3val=&c4stat=&c4comp=&c4val=&c5stat=&c5comp=&c6mult=&c6stat=&order_by=player&order_by_asc=&offset={}".format(str(offset*100))
    
    # this is the HTML from the given URL
    html = urlopen(url)
    soup = BeautifulSoup(html)
    # use findALL() to get the column headers
    soup.findAll('tr', limit=2)
    # use getText()to extract the text we need into a list
    headers = [th.getText() for th in soup.findAll('tr', limit=2)[1].findAll('th')]
    # exclude the first column as we will not need the ranking order from Basketball Reference for the analysis
    headers = headers[1:]
    # avoid the first header row
    rows = soup.findAll('tr')[1:]
    
    
    player_stats = [[td.getText() for td in rows[i].findAll('td')]
                for i in range(len(rows))]
    
    stats_adv = pd.concat([stats_adv, pd.DataFrame(player_stats, columns = headers)]).reset_index(drop=True)

# %%
stats_adv = stats_adv[1:]

# %%
stats_adv.head(10)
# Out:
#      Season Age   Tm   Lg               Player   G  GS    MP   PER  3PAr  ...  \
# 1   1996-97  29  POR  NBA  Aleksandar Đorđević   8   0    61  12.5  .438  ...
# 2   2017-18  20  LAL  NBA          Ivica Zubac  43   0   410  15.3  .008  ...
# 3   2016-17  19  LAL  NBA          Ivica Zubac  38  11   609  17.0  .013  ...
# 4   2018-19  22  CLE  NBA           Ante Žižić  59  25  1082  16.2  .000  ...
# 5   2017-18  21  CLE  NBA           Ante Žižić  32   2   214  24.2  .000  ...
# 6   2016-17  22  CHI  NBA          Paul Zipser  44  18   843   6.9  .448  ...
# 7   2017-18  23  CHI  NBA          Paul Zipser  54  12   824   5.2  .470  ...
# 8   2016-17  20  ORL  NBA    Stephen Zimmerman  19   0   108   7.3  .000  ...
# 9   2005-06  24  NJN  NBA    Derrick Zimmerman   2   0    32   5.5  .000  ...
# 10  1996-97  23  TOT  NBA         George Zídek  52   2   376  10.2  .017  ...
#
#    ORtg DRtg   OWS  DWS    WS  WS/48  OBPM  DBPM    BPM  VORP
# 1   116  111   0.1  0.0   0.1   .114   2.0  -0.8    1.1   0.1
# 2   111  107   0.5  0.5   1.0   .118  -1.8  -0.3   -2.0   0.0
# 3   108  110   0.6  0.5   1.1   .086  -1.2  -0.6   -1.7   0.0
# 4   116  117   1.7  0.3   2.0   .087  -1.1  -2.1   -3.2  -0.3
# 5   137  111   0.9  0.2   1.0   .231   1.9  -0.9    1.0   0.2
# 6    96  109  -0.3  0.8   0.5   .030  -4.2  -0.2   -4.4  -0.5
# 7    84  112  -1.1  0.6  -0.6  -.034  -5.5  -0.5   -6.1  -0.8
# 8    86  108  -0.1  0.1   0.0  -.005  -6.6  -1.7   -8.3  -0.2
# 9    88  108   0.0  0.0   0.0   .004  -7.7  -2.7  -10.4  -0.1
# 10  100  111   0.1  0.2   0.3   .034  -4.4  -2.6   -6.9  -0.5
#
# [10 rows x 29 columns]

# %%
stats_adv.shape
# Out:
# (3359, 29)

# %%
stats.loc[stats['Player'] == 'Kobe Bryant']
# Out:
#        Season Age   Tm   Lg       Player   G GS    MP   FG   FGA  ...  BLK  \
# 2971  1996-97  18  LAL  NBA  Kobe Bryant  71  6  15.5  2.5   5.9  ...  0.3
# 2972  1997-98  19  LAL  NBA  Kobe Bryant  79  1  26.0  4.9  11.6  ...  0.5
#
#       TOV   PF   PTS   FG%   2P%   3P%  eFG%   FT%   TS%
# 2971  1.6  1.4   7.6  .417  .437  .375  .477  .819  .544
# 2972  2.0  2.3  15.4  .428  .456  .341  .469  .794  .548
#
# [2 rows x 31 columns]

# %%
df = stats.copy()
df.columns
# Out:
# Index(['Season', 'Age', 'Tm', 'Lg', 'Player', 'G', 'GS', 'MP', 'FG', 'FGA',
#        '2P', '2PA', '3P', '3PA', 'FT', 'FTA', 'ORB', 'DRB', 'TRB', 'AST',
#        'STL', 'BLK', 'TOV', 'PF', 'PTS', 'FG%', '2P%', '3P%', 'eFG%', 'FT%',
#        'TS%'],
#       dtype='object')

# %%
stats_adv.columns
# Out:
# Index(['Season', 'Age', 'Tm', 'Lg', 'Player', 'G', 'GS', 'MP', 'PER', '3PAr',
#        'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%',
#        'ORtg', 'DRtg', 'OWS', 'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM',
#        'VORP'],
#       dtype='object')

# %%
basic_cols = ['Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA',
       '2P', '2PA', '3P', '3PA', 'FT', 'FTA', 'ORB', 'DRB', 'TRB', 'AST',
       'STL', 'BLK', 'TOV', 'PF', 'PTS', 'FG%', '2P%', '3P%', 'eFG%', 'FT%',
       'TS%']

# %%
adv_cols = [ 'PER', '3PAr',
       'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%',
       'ORtg', 'DRtg', 'OWS', 'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM',
       'VORP']

# %%
advdf = stats_adv.copy()

# %%
for col in cols:
    df[col + '_year1'] = 0
    df[col + '_year2'] = 0
    
for col in adv_cols:
    df[col + '_year1'] = 0
    df[col + '_year2'] = 0

# %%
df.columns
# Out:
# Index(['Season', 'Age', 'Tm', 'Lg', 'Player', 'G', 'GS', 'MP', 'FG', 'FGA',
#        ...
#        'WS/48_year1', 'WS/48_year2', 'OBPM_year1', 'OBPM_year2', 'DBPM_year1',
#        'DBPM_year2', 'BPM_year1', 'BPM_year2', 'VORP_year1', 'VORP_year2'],
#       dtype='object', length=129)

# %%
df = df.sort_values(by=['Season'])
advdf = advdf.sort_values(by=['Season'])

# %%
df.head()
# Out:
#        Season Age   Tm   Lg               Player   G  GS    MP   FG   FGA  \
# 1     1996-97  29  POR  NBA  Aleksandar Đorđević   8   0   7.6  1.0   2.0
# 1033  1996-97  24  MIN  NBA       Cherokee Parks  76   0  12.6  1.4   2.7
# 2992  1996-97  22  POR  NBA         Marcus Brown  21   0   8.8  1.3   3.3
# 254   1996-97  22  POR  NBA      Rasheed Wallace  62  56  30.5  6.1  11.0
# 255   1996-97  22  NYK  NBA         John Wallace  68   6  11.6  1.8   3.5
#
#       ... WS/48_year1 WS/48_year2 OBPM_year1 OBPM_year2 DBPM_year1 DBPM_year2  \
# 1     ...           0           0          0          0          0          0
# 1033  ...           0           0          0          0          0          0
# 2992  ...           0           0          0          0          0          0
# 254   ...           0           0          0          0          0          0
# 255   ...           0           0          0          0          0          0
#
#      BPM_year1 BPM_year2 VORP_year1 VORP_year2
# 1            0         0          0          0
# 1033         0         0          0          0
# 2992         0         0          0          0
# 254          0         0          0          0
# 255          0         0          0          0
#
# [5 rows x 129 columns]

# %%
for player in df['Player'].unique():
    playerstats = df.loc[df['Player'] == player].reset_index(drop = True)
    advplayerstats = advdf.loc[advdf['Player'] == player].reset_index(drop = True)
    if len(playerstats) < 2 or len(advplayerstats) < 2:
        df = df.drop(df[df['Player'] == player].index).reset_index(drop = True)
        advdf = advdf.drop(advdf[advdf['Player'] == player].index).reset_index(drop = True)
        continue
    else:
        for col in cols:
            df[col + "_year1"][df[df['Player'] == player].index] = playerstats[col][0]
            df[col + "_year2"][df[df['Player'] == player].index] = playerstats[col][1]
        for col in adv_cols:
            df[col + "_year1"][df[df['Player'] == player].index] = advplayerstats[col][0]
            df[col + "_year2"][df[df['Player'] == player].index] = advplayerstats[col][1]
# Out:
# /Users/coleleppert/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /Users/coleleppert/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /Users/coleleppert/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /Users/coleleppert/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df = df.sort_values(by=['Season']).drop_duplicates(subset ="Player",keep='first').reset_index(drop=True)

# %%
df.drop(columns=[*cols, 'Lg'], inplace = True)

# %%
df.head(15)
# Out:
#      Season              Player Age_year1 Age_year2 Tm_year1 Tm_year2 G_year1  \
# 0   1996-97        Marcus Brown        22        25      POR      DET      21
# 1   1996-97         Brian Evans        23        24      ORL      TOT      14
# 2   1996-97           Tony Delk        23        24      CHH      TOT      61
# 3   1996-97        Reggie Geary        23        24      CLE      SAS      39
# 4   1996-97  Othella Harrington        23        24      HOU      HOU      57
# 5   1996-97          Gary Trent        22        20      POR      POR      82
# 6   1996-97          Darvin Ham        23        24      TOT      WAS      36
# 7   1996-97      Chris Robinson        22        23      VAN      TOT      41
# 8   1996-97          Roy Rogers        23        24      VAN      TOT      82
# 9   1996-97          Malik Rose        22        23      CHH      SAS      54
# 10  1996-97          Devin Gray        24        27      TOT      HOU       6
# 11  1996-97       Erick Dampier        21        22      IND      GSW      72
# 12  1996-97     Kevin Salvadori        26        27      SAC      SAC      23
# 13  1996-97           Ben Davis        24        25      PHO      NYK      20
# 14  1996-97       Emanual Davis        28        29      HOU      HOU      13
#
#    G_year2 GS_year1 GS_year2  ... WS/48_year1 WS/48_year2 OBPM_year1  \
# 0        6        0        0  ...        .105       -.095       -0.9
# 1       72        0        1  ...        .070        .081        0.1
# 2       77        1        9  ...        .087        .022        0.9
# 3       62        0        2  ...        .056        .023       -3.8
# 4       58        1        3  ...        .079        .092       -3.8
# 5       15       28        1  ...        .139       -.092        0.2
# 6       71        3        3  ...        .018        .069       -4.3
# 7       35        6        0  ...        .017       -.034       -2.8
# 8       15       50        0  ...        .037       -.047       -3.4
# 9       53        1        0  ...        .100        .044       -3.6
# 10      21        0        2  ...       -.179        .123      -12.0
# 11      82       21       82  ...        .040        .072       -4.4
# 12      16        0        0  ...       -.007       -.099       -6.2
# 13       7        0        0  ...        .037       -.127       -4.4
# 14      45        0        0  ...        .063        .022       -1.8
#
#    OBPM_year2 DBPM_year1 DBPM_year2 BPM_year1 BPM_year2 VORP_year1 VORP_year2
# 0        -6.7        0.0       -2.6      -1.0      -9.3        0.0       -0.1
# 1        -0.8        0.6       -0.3       0.7      -1.1        0.0        0.2
# 2        -1.1       -0.6       -0.3       0.3      -1.5        0.5        0.2
# 3        -5.6        2.4        2.7      -1.4      -2.9        0.0       -0.2
# 4        -1.7       -0.9       -1.9      -4.7      -3.6       -0.6       -0.3
# 5        -6.6       -0.1       -4.2       0.1     -10.8        1.0       -0.2
# 6        -4.6       -0.2        0.5      -4.5      -4.0       -0.2       -0.3
# 7        -3.8       -0.6       -1.3      -3.3      -5.1       -0.2       -0.3
# 8        -6.5       -0.3       -2.3      -3.7      -8.8       -0.8       -0.2
# 9        -5.3        0.3        0.6      -3.3      -4.8       -0.2       -0.3
# 10       -2.4       -3.2       -0.1     -15.2      -2.6       -0.2        0.0
# 11       -2.2        0.7       -0.2      -3.7      -2.4       -0.4       -0.3
# 12       -9.3        0.2        1.0      -5.9      -8.3       -0.2       -0.1
# 13       -5.6       -2.2      -12.0      -6.6     -17.6       -0.1        0.0
# 14       -2.1        1.2       -1.5      -0.6      -3.6        0.0       -0.3
#
# [15 rows x 100 columns]

# %%
df.loc[df['Player'] == 'Kobe Bryant']
# Out:
#      Season       Player Age_year1 Age_year2 Tm_year1 Tm_year2 G_year1  \
# 31  1996-97  Kobe Bryant        18        19      LAL      LAL      71
#
#    G_year2 GS_year1 GS_year2  ... WS/48_year1 WS/48_year2 OBPM_year1  \
# 31      79        6        1  ...        .079        .147       -0.2
#
#    OBPM_year2 DBPM_year1 DBPM_year2 BPM_year1 BPM_year2 VORP_year1 VORP_year2
# 31        2.2        0.1       -0.8      -0.1       1.4        0.5        1.8
#
# [1 rows x 100 columns]

# %%
all_stars = pd.DataFrame()

# %%
# URL page we will scraping (see image above)
url = "https://www.basketball-reference.com/awards/all_star_by_player.html"
# this is the HTML from the given URL
html = urlopen(url)
soup = BeautifulSoup(html)
# use findALL() to get the column headers
soup.findAll('tr', limit=2)
# use getText()to extract the text we need into a list
headers = [th.getText() for th in soup.findAll('tr', limit=2)[0].findAll('th')]
# exclude the first column as we will not need the ranking order from Basketball Reference for the analysis
#headers = headers[1:]
# avoid the first header row
rows = soup.findAll('tr')[1:]
players = [[td.getText() for td in rows[i].findAll('td')]
            for i in range(len(rows))]
print(headers)
all_stars = pd.concat([all_stars, pd.DataFrame(players, columns = headers)]).reset_index(drop=True)
# Out:
# ['Rk', 'Player', 'Tot', 'NBA', 'ABA']

# %%
# List of all all stars in NBA history
all_stars.head()
# Out:
#   Rk               Player Tot NBA ABA
# 0  1  Kareem Abdul-Jabbar  19  19   0
# 1  2          Kobe Bryant  18  18   0
# 2  3        Julius Erving  16  11   5
# 3  4         LeBron James  16  16   0
# 4  5           Tim Duncan  15  15   0

# %%
allStarDict = {}
for player, num in zip(all_stars['Player'], all_stars['Tot']):
    allStarDict[player] = num

# %%
df['all_star'] = df['Player'].apply(lambda x: 1 if x in allStarDict else 0)

# %%
df[df['all_star'] == 1]
# Out:
#        Season            Player Age_year1 Age_year2 Tm_year1 Tm_year2 G_year1  \
# 16    1996-97   Stephon Marbury        19        20      MIN      MIN      67
# 31    1996-97       Kobe Bryant        18        19      LAL      LAL      71
# 32    1996-97    Antoine Walker        20        21      BOS      BOS      82
# 33    1996-97     Allen Iverson        21        22      PHI      PHI      76
# 40    1996-97       Ben Wallace        22        23      WSB      WAS      34
# ...       ...               ...       ...       ...      ...      ...     ...
# 1201  2017-18       Ben Simmons        21        22      PHI      PHI      81
# 1252  2017-18      Jayson Tatum        19        20      BOS      BOS      80
# 1270  2017-18  Donovan Mitchell        21        22      UTA      UTA      79
# 1285  2018-19       Luka Dončić        19        20      DAL      DAL      72
# 1340  2018-19        Trae Young        20        21      ATL      ATL      81
#
#      G_year2 GS_year1 GS_year2  ... WS/48_year2 OBPM_year1 OBPM_year2  \
# 16        82       64       81  ...        .082        2.2        1.9
# 31        79        6        1  ...        .147       -0.2        2.2
# 32        82       68       82  ...        .070       -0.3        1.6
# 33        80       74       80  ...        .138        2.5        3.5
# 40        67        0       16  ...        .125       -7.6       -1.6
# ...      ...      ...      ...  ...         ...        ...        ...
# 1201      79       81       79  ...        .146        2.0        2.2
# 1252      79       80       79  ...        .097        0.0       -0.4
# 1270      77       71       77  ...        .092        0.9        1.2
# 1285      60       72       60  ...        .206        3.6        7.3
# 1340      60       81       60  ...        .133        2.3        6.3
#
#      DBPM_year1 DBPM_year2 BPM_year1 BPM_year2 VORP_year1 VORP_year2 all_star
# 16         -2.3       -2.0       0.0      -0.1        1.2        1.5        1
# 31          0.1       -0.8      -0.1       1.4        0.5        1.8        1
# 32         -1.8       -1.0      -2.1       0.6       -0.1        2.2        1
# 33         -1.6        0.1       0.9       3.6        2.2        4.5        1
# 40         -0.7        2.3      -8.3       0.7       -0.3        0.8        1
# ...         ...        ...       ...       ...        ...        ...      ...
# 1201        2.5        1.3       4.5       3.6        4.5        3.8        1
# 1252        1.2        0.2       1.2      -0.2        2.0        1.1        1
# 1270        0.3        0.1       1.2       1.3        2.2        2.2        1
# 1285        0.3        1.0       3.9       8.3        3.4        5.3        1
# 1340       -2.8       -2.3      -0.6       4.0        0.9        3.2        1
#
# [123 rows x 101 columns]

# %%
rising_stars = pd.DataFrame()

# %%
for year in range(2000,2021):
    # URL page we will scraping (see image above)
    url = "https://www.basketball-reference.com/allstar/NBA_{}_rookie.html".format(year)
    # this is the HTML from the given URL
    html = urlopen(url)
    soup = BeautifulSoup(html)
    # use findALL() to get the column headers
    soup.findAll('tr', limit=2)
    # use getText()to extract the text we need into a list
    headers = [th.getText() for th in soup.findAll('tr', limit=6)[5].findAll('th')]
    # exclude the first column as we will not need the ranking order from Basketball Reference for the analysis
    headers = headers
    # avoid the first header row
    rows = soup.findAll('tr')
    players = [[td.getText() for td in rows[i].findAll(['td','th'])] for i in range(len(rows))]
    rising_stars = pd.concat([rising_stars, pd.DataFrame(players, columns = headers)]).reset_index(drop=True)

# %%
# List of all rising stars in NBA

#CLEAN THIS UP
rising_stars
# Out:
#          Player       Tm        MP    FG   FGA    3P   3PA    FT   FTA   ORB  \
# 0                Scoring      None  None  None  None  None  None  None  None
# 1                      1         2    OT     T  None  None  None  None  None
# 2       Rookies       44        37    11    92  None  None  None  None  None
# 3    Sophomores       41        40     2    83  None  None  None  None  None
# 4                 Totals  Shooting  None  None  None  None  None  None  None
# ..          ...      ...       ...   ...   ...   ...   ...   ...   ...   ...
# 656         NaN      WAS     16:15     6     9     1     2     3     4     3
# 657         NaN      DET     16:15     2    11     2     9     0     0     1
# 658         NaN      MIN     16:15     2     5     1     4     0     0     2
# 659         NaN      NOP     16:15     1     3     1     2     0     0     1
# 660         NaN                200    55   109    12    49     9    12    14
#
#      ...   AST   STL   BLK   TOV    PF   PTS   FG%   3P%   FT%  \
# 0    ...  None  None  None  None  None  None  None  None  None
# 1    ...  None  None  None  None  None  None  None  None  None
# 2    ...  None  None  None  None  None  None  None  None  None
# 3    ...  None  None  None  None  None  None  None  None  None
# 4    ...  None  None  None  None  None  None  None  None  None
# ..   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 656  ...     0     2     0     0     2    16  .667  .500  .750
# 657  ...     2     0     0     1     0     6  .182  .222
# 658  ...     5     0     1     5     1     5  .400  .250
# 659  ...     2     0     0     1     0     3  .333  .500
# 660  ...    32     9     3    12     8   131  .505  .245  .750
#
#                   Starters
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ..                     ...
# 656          Moritz Wagner
# 657  Sviatoslav Mykhailiuk
# 658            Josh Okogie
# 659           Nicolò Melli
# 660            Team Totals
#
# [661 rows x 22 columns]

# %%
risingstarsDict = {}
for player in rising_stars['Starters']:
    risingstarsDict[player] = 1

# %%
df['rising_star'] = df['Player'].apply(lambda x: 1 if x in risingstarsDict else 0)

# %%
df.head()
# Out:
#     Season              Player Age_year1 Age_year2 Tm_year1 Tm_year2 G_year1  \
# 0  1996-97        Marcus Brown        22        25      POR      DET      21
# 1  1996-97         Brian Evans        23        24      ORL      TOT      14
# 2  1996-97           Tony Delk        23        24      CHH      TOT      61
# 3  1996-97        Reggie Geary        23        24      CLE      SAS      39
# 4  1996-97  Othella Harrington        23        24      HOU      HOU      57
#
#   G_year2 GS_year1 GS_year2  ... OBPM_year1 OBPM_year2 DBPM_year1 DBPM_year2  \
# 0       6        0        0  ...       -0.9       -6.7        0.0       -2.6
# 1      72        0        1  ...        0.1       -0.8        0.6       -0.3
# 2      77        1        9  ...        0.9       -1.1       -0.6       -0.3
# 3      62        0        2  ...       -3.8       -5.6        2.4        2.7
# 4      58        1        3  ...       -3.8       -1.7       -0.9       -1.9
#
#   BPM_year1 BPM_year2 VORP_year1 VORP_year2 all_star rising_star
# 0      -1.0      -9.3        0.0       -0.1        0           0
# 1       0.7      -1.1        0.0        0.2        0           0
# 2       0.3      -1.5        0.5        0.2        0           0
# 3      -1.4      -2.9        0.0       -0.2        0           0
# 4      -4.7      -3.6       -0.6       -0.3        0           0
#
# [5 rows x 102 columns]

# %%
df[df['rising_star'] == 1]
# Out:
#        Season                 Player Age_year1 Age_year2 Tm_year1 Tm_year2  \
# 383   2003-04             David West        23        24      NOH      NOH
# 424   2003-04              T.J. Ford        20        22      MIL      MIL
# 427   2004-05              Luol Deng        19        20      CHI      CHI
# 431   2004-05          Dwight Howard        19        20      ORL      ORL
# 434   2004-05             Ben Gordon        21        22      CHI      CHI
# ...       ...                    ...       ...       ...      ...      ...
# 1334  2018-19          Collin Sexton        20        21      CLE      CLE
# 1336  2018-19          Jaren Jackson        19        20      MEM      MEM
# 1340  2018-19             Trae Young        20        21      ATL      ATL
# 1341  2018-19  Sviatoslav Mykhailiuk        21        22      TOT      DET
# 1344  2018-19          Deandre Ayton        20        21      PHO      PHO
#
#      G_year1 G_year2 GS_year1 GS_year2  ... OBPM_year1 OBPM_year2 DBPM_year1  \
# 383       71      30        1        8  ...       -0.8       -3.3        0.3
# 424       55      72       55       70  ...       -1.7       -1.1       -0.6
# 427       61      78       45       56  ...        0.2        0.8        1.0
# 431       82      82       82       81  ...        0.1        1.1       -0.1
# 434       82      80        3       47  ...        1.0        0.7       -0.3
# ...      ...     ...      ...      ...  ...        ...        ...        ...
# 1334      82      65       72       65  ...       -1.4        0.3       -3.3
# 1336      58      57       56       57  ...       -1.2        0.3        1.0
# 1340      81      60       81       60  ...        2.3        6.3       -2.8
# 1341      42      56        0       27  ...       -3.9       -0.7       -1.1
# 1344      71      37       70       31  ...        1.3        0.7       -1.1
#
#      DBPM_year2 BPM_year1 BPM_year2 VORP_year1 VORP_year2 all_star rising_star
# 383         0.1      -0.5      -3.2        0.4       -0.2        1           1
# 424        -0.1      -2.4      -1.2       -0.1        0.5        0           1
# 427         0.9       1.2       1.6        1.3        2.4        1           1
# 431        -0.1       0.0       1.0        1.4        2.3        1           1
# 434        -0.3       0.7       0.5        1.4        1.6        0           1
# ...         ...       ...       ...        ...        ...      ...         ...
# 1334       -2.1      -4.7      -1.8       -1.8        0.1        0           1
# 1336        0.1      -0.3       0.4        0.7        1.0        0           1
# 1340       -2.3      -0.6       4.0        0.9        3.2        1           1
# 1341       -1.2      -5.0      -1.8       -0.3        0.0        0           1
# 1344       -0.6       0.2       0.1        1.2        0.7        0           1
#
# [194 rows x 102 columns]

# %%
df.to_csv('../Data/nba-stats-first2seasons.csv', index=False)
